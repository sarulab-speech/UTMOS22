# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import joblib
from pathlib import Path
import pickle
import gpytorch
import json

# %%
from models import Ridge
from gp_models import ExactGPModel

# %%
df_data = pd.read_csv('../out/ensemble-multidomain/data-stage2/phase1-main/main4-weak48s-indomain-opt/test-X.csv', index_col=0)
column_names = df_data.columns.values
column_names
# Out:
# array(['pred-fancy-surf-27', 'pred-polar-flower-28',
#        'pred-likely-leaf-29', 'pred-cosmic-water-30',
#        'pred-phase1-main---ridge---w2v_small',
#        'pred-phase1-main---ridge---w2v_large',
#        'pred-phase1-main---ridge---w2v_large2',
#        'pred-phase1-main---ridge---w2v_xlsr',
#        'pred-phase1-main---ridge---hubert_base',
#        'pred-phase1-main---ridge---hubert_large',
#        'pred-phase1-main---ridge---wavlm_base',
#        'pred-phase1-main---ridge---wavlm_large',
#        'pred-phase1-main---linear_svr---w2v_small',
#        'pred-phase1-main---linear_svr---w2v_large',
#        'pred-phase1-main---linear_svr---w2v_large2',
#        'pred-phase1-main---linear_svr---w2v_xlsr',
#        'pred-phase1-main---linear_svr---hubert_base',
#        'pred-phase1-main---linear_svr---hubert_large',
#        'pred-phase1-main---linear_svr---wavlm_base',
#        'pred-phase1-main---linear_svr---wavlm_large',
#        'pred-phase1-main---kernel_svr---w2v_small',
#        'pred-phase1-main---kernel_svr---w2v_large',
#        'pred-phase1-main---kernel_svr---w2v_large2',
#        'pred-phase1-main---kernel_svr---w2v_xlsr',
#        'pred-phase1-main---kernel_svr---hubert_base',
#        'pred-phase1-main---kernel_svr---hubert_large',
#        'pred-phase1-main---kernel_svr---wavlm_base',
#        'pred-phase1-main---kernel_svr---wavlm_large',
#        'pred-phase1-main---lightgbm---w2v_small',
#        'pred-phase1-main---lightgbm---w2v_large',
#        'pred-phase1-main---lightgbm---w2v_large2',
#        'pred-phase1-main---lightgbm---w2v_xlsr',
#        'pred-phase1-main---lightgbm---hubert_base',
#        'pred-phase1-main---lightgbm---hubert_large',
#        'pred-phase1-main---lightgbm---wavlm_base',
#        'pred-phase1-main---lightgbm---wavlm_large',
#        'pred-phase1-main---rf---w2v_small',
#        'pred-phase1-main---rf---w2v_large',
#        'pred-phase1-main---rf---w2v_large2',
#        'pred-phase1-main---rf---w2v_xlsr',
#        'pred-phase1-main---rf---hubert_base',
#        'pred-phase1-main---rf---hubert_large',
#        'pred-phase1-main---rf---wavlm_base',
#        'pred-phase1-main---rf---wavlm_large',
#        'mean-phase1-main---exactgp---w2v_small',
#        'lower-phase1-main---exactgp---w2v_small',
#        'upper-phase1-main---exactgp---w2v_small',
#        'mean-phase1-main---exactgp---w2v_large',
#        'lower-phase1-main---exactgp---w2v_large',
#        'upper-phase1-main---exactgp---w2v_large',
#        'mean-phase1-main---exactgp---w2v_large2',
#        'lower-phase1-main---exactgp---w2v_large2',
#        'upper-phase1-main---exactgp---w2v_large2',
#        'mean-phase1-main---exactgp---w2v_xlsr',
#        'lower-phase1-main---exactgp---w2v_xlsr',
#        'upper-phase1-main---exactgp---w2v_xlsr',
#        'mean-phase1-main---exactgp---hubert_base',
#        'lower-phase1-main---exactgp---hubert_base',
#        'upper-phase1-main---exactgp---hubert_base',
#        'mean-phase1-main---exactgp---hubert_large',
#        'lower-phase1-main---exactgp---hubert_large',
#        'upper-phase1-main---exactgp---hubert_large',
#        'mean-phase1-main---exactgp---wavlm_base',
#        'lower-phase1-main---exactgp---wavlm_base',
#        'upper-phase1-main---exactgp---wavlm_base',
#        'mean-phase1-main---exactgp---wavlm_large',
#        'lower-phase1-main---exactgp---wavlm_large',
#        'upper-phase1-main---exactgp---wavlm_large'], dtype=object)

# %%
df_weight_list = []
for i in range(5):
    ridge_model = joblib.load(f'../out/ensemble-multidomain/stage2/phase1-main/ridge-main4-weak48s-indomain-opt/{i}/model.joblib')
    df_weight_list.append(pd.Series(dict(zip(column_names, ridge_model.coef_))))
df_weight = pd.concat(df_weight_list, axis=1)
df_weight.shape
# Out:
# (68, 5)

# %%
df_weight.columns.values
# Out:
# array([0, 1, 2, 3, 4])

# %%
fig, axes = plt.subplots(5,1,figsize=(10,20), sharex=True)
for i in range(5):
    ax = axes[i]
    df_weight.loc[:, i].plot.bar(ax=ax)
    ax.set_ylabel(f'Weight-fold{i}')
    ax.set_xlabel('Stage1 method')
plt.tight_layout()
fig.savefig('./fig/main-ridge_coef.pdf')

# %%
# !mkdir -p fig

# %%
# initial_inducing = torch.from_numpy(np.empty((1024, len(column_names)), dtype=np.float32))
# initial_inducing.size()
# Out:
# torch.Size([1024, 43])

# %%
df_lengthscale_list = []
for i in range(5):
    model_dir = Path(f'../out/ensemble-multidomain/stage2/phase1-main/exactgp-main4-weak48s-indomain-opt/{i}')
    conf = json.load(open(model_dir / 'model_config.json', 'rb'))
    dummy_X = torch.from_numpy(
        np.empty(conf['input_shape'], dtype=np.float32))
    dummy_y = torch.from_numpy(
        np.empty(conf['output_shape'], dtype=np.float32))
    likelihood = gpytorch.likelihoods.GaussianLikelihood(
                    noise_constraint=gpytorch.constraints.GreaterThan(1e-3),
                )
    gpr = ExactGPModel(dummy_X, dummy_y, likelihood,
                        initial_lengthscale=1.0)
    gpr.load_state_dict(torch.load(model_dir / 'model.pt', map_location='cpu'))
    lengthscale = gpr.covar_module.base_kernel.lengthscale.detach().numpy().ravel()
    df_lengthscale_list.append(pd.Series(dict(zip(column_names, lengthscale))))
    
df_lengthscale = pd.concat(df_lengthscale_list, axis=1)
df_lengthscale.shape
# Out:
# (68, 5)

# %%
fig, axes = plt.subplots(5,1,figsize=(10,20), sharex=True)
for i in range(5):
    ax = axes[i]
    df_lengthscale.loc[:, i].plot.bar(ax=ax)
    ax.set_ylabel(f'Lengthscale-fold{i}')
    ax.set_xlabel('Stage1 method')
plt.tight_layout()
fig.savefig('./fig/main-exactgp_lengthscale.pdf')

# %%
df_importance_list = []
for i in range(5):
    lgb_path = f'../out/ensemble-multidomain/stage2/phase1-main/lightgbm-main4-weak48s-indomain-opt/{i}/model.pkl'
    lgb = pickle.load(open(lgb_path, 'rb'))
    df_importance_list.append(pd.Series(dict(zip(column_names, lgb.feature_importance()))))
df_importance = pd.concat(df_importance_list, axis=1)
df_importance.shape
# Out:
# (68, 5)

# %%
fig, axes = plt.subplots(5,1,figsize=(10,20), sharex=True)
for i in range(5):
    ax = axes[i]
    df_importance.loc[:, i].plot.bar(ax=ax)
    ax.set_ylabel(f'Importance-fold{i}')
    ax.set_xlabel('Stage1 method')
plt.tight_layout()
fig.savefig('./fig/main-lightgbm_importance.pdf')
